# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import statsmodels.stats.multicomp as multi
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
aus_crime_stats
# Out:
#    This tab outlines the contents of the datacube and includes links to relevant webpages on the ABS website. It ranges from cell A1 to B25.  \
# 0                     Australian Bureau of Statistics
# 1                 Recorded Crime – Offenders, 2023–24
# 2   Released at 11.30am (Canberra time) Thursday 6...
# 3                                            Contents
# 4                                                 Tab
# 5                                             Table 6
# 6                                             Table 7
# 7                                             Table 8
# 8                                             Table 9
# 9                                            Table 10
# 10                                           Table 11
# 11                                           Table 12
# 12                                           Table 13
# 13                                           Table 14
# 14                                           Table 15
# ...

# %%
new = pd.read_excel("/Users/waqarmohiuddin/Library/Mobile Documents/com~apple~Numbers/Documents/crime_stats.xlsx.numbers")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 new = pd.read_excel("/Users/waqarmohiuddin/Library/Mobile Documents/com~apple~Numbers/Documents/crime_stats.xlsx.numbers")
#
# File /opt/anaconda3/envs/crimeenv/lib/python3.11/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
xls = pd.ExcelFile("/Users/waqarmohiuddin/Downloads/Recorded Crime - Offenders, 2023-24/3. Youth offenders.xlsx")
xls.sheet_names
# Out:
# ['Contents',
#  'Table 18',
#  'Table 19',
#  'Table 20',
#  'Table 21',
#  'Table 22',
#  'Table 23',
#  'Table 24',
#  'Table 25']

# %%
youth_offenders = pd.read_excel("/Users/waqarmohiuddin/Downloads/Recorded Crime - Offenders, 2023-24/3. Youth offenders.xlsx", sheet_name="Table 21")

# %%
youth_offenders = pd.read_excel(
    "/Users/waqarmohiuddin/Downloads/Recorded Crime - Offenders, 2023-24/3. Youth offenders.xlsx",
    sheet_name= "Table 21",
    skiprows=4,     # skip metadata rows
    nrows=157       # table is A1–K161 → about 157 data rows
)

youth_offenders.head()
# Out:
#                                Unnamed: 0           Number   Unnamed: 2  \
# 0                 Principal offence(b)(c)      10–11 years  12–13 years
# 1                                     NaN  New South Wales          NaN
# 2        01 Homicide and related offences                0            0
# 3     02 Acts intended to cause injury(e)               58          675
# 4  03 Sexual assault and related offences                0           36
#
#     Unnamed: 3       Unnamed: 4        Unnamed: 5 Offender rate(a)  \
# 0  14–17 years  Youth offenders  All offenders(d)      10–11 years
# 1          NaN              NaN               NaN              NaN
# 2           19               18               267                0
# 3         3368             4100             38453             28.1
# 4          226              259              2872                0
#
#     Unnamed: 7   Unnamed: 8       Unnamed: 9  ... Unnamed: 16374  \
# ...
